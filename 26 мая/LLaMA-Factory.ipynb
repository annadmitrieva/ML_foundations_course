# %% [markdown]
# # Finetune Llama-3 with LLaMA Factory
#
# Please use a **free** Tesla T4 Colab GPU to run this!
#
# Project homepage: https://github.com/hiyouga/LLaMA-Factory

# %% [markdown]
# ## Install Dependencies

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install -e .[torch,bitsandbytes,unsloth]
# Out:
# /content
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 356, done.
# remote: Counting objects: 100% (356/356), done.
# remote: Compressing objects: 100% (275/275), done.
# remote: Total 356 (delta 76), reused 267 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (356/356), 9.72 MiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/LLaMA-Factory
# assets/       evaluation/  MANIFEST.in     requirements.txt  tests/
# CITATION.cff  examples/    pyproject.toml  scripts/
# data/         LICENSE      README.md       setup.py
# docker/       Makefile     README_zh.md    src/
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers!=4.46.*,!=4.47.*,!=4.48.0,!=4.52.0,<=4.52.1,>=4.45.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (4.51.3)
# Collecting datasets<=3.6.0,>=2.16.0 (from llamafactory==0.9.3.dev0)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: accelerate<=1.7.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (1.6.0)
# Requirement already satisfied: peft<=0.15.2,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.15.2)
# Collecting trl<=0.9.6,>=0.8.6 (from llamafactory==0.9.3.dev0)
#   Downloading trl-0.9.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tokenizers<=0.21.1,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.21.1)
# Collecting gradio<=5.30.0,>=4.38.0 (from llamafactory==0.9.3.dev0)
#   Downloading gradio-5.30.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (1.15.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.2.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.9.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (5.29.4)
# Collecting uvicorn (from llamafactory==0.9.3.dev0)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Collecting fastapi (from llamafactory==0.9.3.dev0)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting sse-starlette (from llamafactory==0.9.3.dev0)
#   Downloading sse_starlette-2.3.5-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (3.10.0)
# Collecting fire (from llamafactory==0.9.3.dev0)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (2.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (24.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (6.0.2)
# Collecting numpy<2.0.0 (from llamafactory==0.9.3.dev0)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.4 MB/s eta 0:00:00
# Collecting pydantic<=2.10.6 (from llamafactory==0.9.3.dev0)
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (2.2.2)
# Collecting av (from llamafactory==0.9.3.dev0)
#   Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.11.0)
# Collecting tyro<0.9.0 (from llamafactory==0.9.3.dev0)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# WARNING: llamafactory 0.9.3.dev0 does not provide the extra 'unsloth'
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from llamafactory==0.9.3.dev0) (0.21.0+cu124)
# Collecting bitsandbytes>=0.39.0 (from llamafactory==0.9.3.dev0)
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.7.0,>=0.34.0->llamafactory==0.9.3.dev0) (5.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.7.0,>=0.34.0->llamafactory==0.9.3.dev0) (0.31.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate<=1.7.0,>=0.34.0->llamafactory==0.9.3.dev0) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.3.7)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.70.15)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (4.9.0)
# Collecting ffmpy (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.10.1 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading gradio_client-1.10.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.10.18)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (11.2.1)
# Collecting pydub (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading ruff-0.11.11-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (0.15.3)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (4.13.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.3.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->llamafactory==0.9.3.dev0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<=2.10.6->llamafactory==0.9.3.dev0) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic<=2.10.6->llamafactory==0.9.3.dev0)
#   Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (3.4.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->llamafactory==0.9.3.dev0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->llamafactory==0.9.3.dev0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->llamafactory==0.9.3.dev0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.46.*,!=4.47.*,!=4.48.0,!=4.52.0,<=4.52.1,>=4.45.0->llamafactory==0.9.3.dev0) (2024.11.6)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.3.dev0) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.11/dist-packages (from tyro<0.9.0->llamafactory==0.9.3.dev0) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro<0.9.0->llamafactory==0.9.3.dev0)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.3.dev0) (8.2.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->llamafactory==0.9.3.dev0) (0.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->llamafactory==0.9.3.dev0) (3.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.5.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa->llamafactory==0.9.3.dev0) (1.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf->llamafactory==0.9.3.dev0) (4.9.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.3.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.11.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.0.9)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa->llamafactory==0.9.3.dev0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa->llamafactory==0.9.3.dev0) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->llamafactory==0.9.3.dev0) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (2.19.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa->llamafactory==0.9.3.dev0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa->llamafactory==0.9.3.dev0) (1.17.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio<=5.30.0,>=4.38.0->llamafactory==0.9.3.dev0) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=3.6.0,>=2.16.0->llamafactory==0.9.3.dev0) (1.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->llamafactory==0.9.3.dev0) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.3.dev0) (0.1.2)
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 12.3 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 38.3 MB/s eta 0:00:00
# Downloading gradio-5.30.0-py3-none-any.whl (54.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 MB 13.8 MB/s eta 0:00:00
# Downloading gradio_client-1.10.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 27.6 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.4 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 114.4 MB/s eta 0:00:00
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.7/431.7 kB 35.8 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 80.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 97.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.0 MB/s eta 0:00:00
# Downloading trl-0.9.6-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 24.2 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 12.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.2 MB/s eta 0:00:00
# Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 59.2 MB/s eta 0:00:00
# Downloading sse_starlette-2.3.5-py3-none-any.whl (10 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 20.0 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.11.11-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 125.5 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.7 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: llamafactory, fire
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.3.dev0-0.editable-py3-none-any.whl size=27231 sha256=d11d702a6c7ecf30af0aaf9859313506fcf0d9d8c25ba9c37cb6110b1deee0d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0_4t2nry/wheels/bd/34/05/1e3cb4b8f20c20631b411dc5157b4b150850c03496fa96c2c4
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=12ef41ac0438cc25f86dee127799462c35e2fb058371b226ee9678e7f707cd0e
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built llamafactory fire
# Installing collected packages: pydub, uvicorn, tomlkit, shtab, semantic-version, ruff, python-multipart, pydantic-core, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, groovy, fsspec, fire, ffmpy, av, aiofiles, starlette, pydantic, nvidia-cusparse-cu12, nvidia-cudnn-cu12, tyro, sse-starlette, safehttpx, nvidia-cusolver-cu12, gradio-client, fastapi, gradio, datasets, bitsandbytes, trl, llamafactory
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.2
#     Uninstalling pydantic_core-2.33.2:
#       Successfully uninstalled pydantic_core-2.33.2
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.4
#     Uninstalling pydantic-2.11.4:
#       Successfully uninstalled pydantic-2.11.4
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed aiofiles-24.1.0 av-14.4.0 bitsandbytes-0.45.5 datasets-3.6.0 fastapi-0.115.12 ffmpy-0.5.0 fire-0.7.0 fsspec-2025.3.0 gradio-5.30.0 gradio-client-1.10.1 groovy-0.1.2 llamafactory-0.9.3.dev0 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pydantic-2.10.6 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.11.11 safehttpx-0.1.6 semantic-version-2.10.0 shtab-1.7.2 sse-starlette-2.3.5 starlette-0.46.2 tomlkit-0.13.2 trl-0.9.6 tyro-0.8.14 uvicorn-0.34.2

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/ML_training_data/zlatoust_sentence_aligned_with_CATS.csv')

# %%
df = df.loc[(df['cos_sim'] >= 0.33)&(df['cos_sim'] < 0.98)]

# %%
df['instruction'] = "Напиши упрощенную версию текста на русском языке."

# %%
train_df, extra = train_test_split(df, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(extra, test_size=0.5, random_state=42)

# %%
def df_to_llamafactory_json(df):
  dicts = []
  for n, row in df.iterrows():
    d = {}
    d["instruction"] = row['instruction']
    d["input"] = row['source']
    d["output"] = row['target']
    dicts.append(d)
  return dicts

# %%
train_data = df_to_llamafactory_json(train_df)
test_data = df_to_llamafactory_json(val_df)
val_data = df_to_llamafactory_json(test_df)

# %%
test_data[:5]
# Out:
# [{'instruction': 'Напиши упрощенную версию текста на русском языке.',
#   'input': 'Говоря это, я привстал со скамейки. ',
#   'output': 'Говоря это, я встал со скамейки. '},
#  {'instruction': 'Напиши упрощенную версию текста на русском языке.',
#   'input': 'Ты сам сказал: отдать кафтан, когда берут рубашку, и теперь… –\xa0Я прошу, – вдруг вставая на ноги, бледный и с трясущеюся челюстью, пискливым голосом заговорил Алексей Александрович, – прошу вас прекратить, прекратить… этот разговор',
#   'output': '— Я прошу, — вдруг вставая, бледный, тонким голосом заго ворил Алексей Александрович, — прошу вас прекратить… этот разговор. '},
#  {'instruction': 'Напиши упрощенную версию текста на русском языке.',
#   'input': 'Я не мужа обманула, а самое себя. ',
#   'output': 'Я не мужа обманула, а себя. '},
#  {'instruction': 'Напиши упрощенную версию текста на русском языке.',
#   'input': 'Я не предполагаю отказа, зная великодушие того, от кого оно зависит. ',
#   'output': 'Я не предполагаю отказа, зная великодушие того, от кого оно зависит". '},
#  {'instruction': 'Напиши упрощенную версию текста на русском языке.',
#   'input': 'Князь снял запор, отворил дверь и - отступил в изумлении, весь даже вздрогнул: пред ним стояла Настасья Филипповна. ',
#   'output': 'Князь открыл дверь и — остановился в изумлении, весь даже вздрог-нул: пред ним стояла Настасья Филипповна. '}]

# %%
import json

with open('/content/LLaMA-Factory/data/zlatoust_train.json', 'w') as f:
  json.dump(train_data, f, ensure_ascii = False)

with open('/content/LLaMA-Factory/data/zlatoust_val.json', 'w') as f:
  json.dump(val_data, f, ensure_ascii = False)

with open('/content/LLaMA-Factory/data/zlatoust_test.json', 'w') as f:
  json.dump(test_data, f, ensure_ascii = False)

# %%
with open('/content/LLaMA-Factory/data/dataset_info.json', 'r') as f:
  dataset_info = json.load(f)

# %%
dataset_info["zlatoust_train"] = {"file_name": "zlatoust_train.json"}
dataset_info["zlatoust_val"] = {"file_name": "zlatoust_val.json"}
dataset_info["zlatoust_test"] = {"file_name": "zlatoust_test.json"}

# %%
with open('/content/LLaMA-Factory/data/dataset_info.json', 'w') as f:
  json.dump(dataset_info, f)

# %% [markdown]
# ## Fine-tune model via LLaMA Board

# %%
# %cd /content/LLaMA-Factory/
# !GRADIO_SHARE=1 llamafactory-cli webui
# Out:
# /content/LLaMA-Factory
# 2025-05-26 08:38:26.285344: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748248706.305402    3732 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748248706.311662    3732 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-26 08:38:26.332928: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Visit http://ip:port for Web UI, e.g., http://127.0.0.1:7860
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://500a7d93a2097e6958.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2025-05-26 08:41:15.597582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748248875.629802    4457 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748248875.644064    4457 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [INFO|2025-05-26 08:41:23] llamafactory.hparams.parser:401 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.bfloat16
# tokenizer_config.json: 100% 1.29k/1.29k [00:00<00:00, 7.93MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 24.8MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 31.1MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 35.7MB/s]
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,433 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/vocab.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/merges.txt
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:24,434 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2323] 2025-05-26 08:41:24,824 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 5.69MB/s]
# [INFO|configuration_utils.py:693] 2025-05-26 08:41:25,142 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:41:25,149 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,197 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/vocab.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/merges.txt
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:41:25,198 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2323] 2025-05-26 08:41:25,584 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-05-26 08:41:25] llamafactory.data.loader:143 >> Loading dataset zlatoust_val.json...
# Setting num_proc from 16 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# WARNING:datasets.builder:Setting num_proc from 16 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 2214 examples [00:00, 28299.56 examples/s]
# Converting format of dataset (num_proc=16): 100% 2214/2214 [00:00<00:00, 2861.41 examples/s]
# Running tokenizer on dataset (num_proc=16): 100% 2214/2214 [00:13<00:00, 166.73 examples/s]
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 1207, 16948, 11, 3465, 553, 54364, 14817, 13, 1446, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 20195, 19077, 1802, 29380, 13932, 124436, 91406, 138811, 63262, 124662, 11916, 70895, 1478, 13073, 18108, 43055, 129743, 45310, 125670, 52571, 624, 2293, 22933, 17273, 125626, 1478, 137882, 1504, 32642, 14191, 0, 220, 151645, 198, 151644, 77091, 198, 2293, 52577, 6949, 26988, 20200, 82580, 50527, 11, 22933, 17273, 125626, 1478, 137882, 1504, 32642, 14191, 13, 220, 151645, 198]
# inputs:
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Напиши упрощенную версию текста на русском языке.
# — Варвара Андреевна! <|im_end|>
# <|im_start|>assistant
# — Здравствуйте, Варвара Андреевна. <|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 2293, 52577, 6949, 26988, 20200, 82580, 50527, 11, 22933, 17273, 125626, 1478, 137882, 1504, 32642, 14191, 13, 220, 151645, 198]
# labels:
# — Здравствуйте, Варвара Андреевна. <|im_end|>
#
# [INFO|configuration_utils.py:693] 2025-05-26 08:41:41,720 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:41:41,721 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2025-05-26 08:41:41] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors: 100% 988M/988M [00:10<00:00, 97.9MB/s]
# [INFO|modeling_utils.py:1124] 2025-05-26 08:41:52,548 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/model.safetensors
# [INFO|modeling_utils.py:2167] 2025-05-26 08:41:52,550 >> Instantiating Qwen2ForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1142] 2025-05-26 08:41:52,552 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [WARNING|logging.py:328] 2025-05-26 08:41:52,565 >> Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# [INFO|modeling_utils.py:4930] 2025-05-26 08:41:53,057 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4938] 2025-05-26 08:41:53,058 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at Qwen/Qwen2-0.5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# generation_config.json: 100% 242/242 [00:00<00:00, 2.26MB/s]
# [INFO|configuration_utils.py:1097] 2025-05-26 08:41:53,163 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/generation_config.json
# [INFO|configuration_utils.py:1142] 2025-05-26 08:41:53,163 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# [INFO|2025-05-26 08:41:53] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2025-05-26 08:41:53] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-05-26 08:41:53] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2025-05-26 08:41:53] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2025-05-26 08:41:53] llamafactory.model.model_utils.misc:143 >> Found linear modules: up_proj,o_proj,down_proj,k_proj,gate_proj,q_proj,v_proj
# [INFO|2025-05-26 08:41:54] llamafactory.model.loader:143 >> trainable params: 4,399,104 || all params: 498,431,872 || trainable%: 0.8826
# [INFO|trainer.py:748] 2025-05-26 08:41:54,272 >> Using auto half precision backend
# [INFO|trainer.py:2414] 2025-05-26 08:41:54,783 >> ***** Running training *****
# [INFO|trainer.py:2415] 2025-05-26 08:41:54,783 >>   Num examples = 2,214
# [INFO|trainer.py:2416] 2025-05-26 08:41:54,783 >>   Num Epochs = 3
# [INFO|trainer.py:2417] 2025-05-26 08:41:54,783 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2420] 2025-05-26 08:41:54,783 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:2421] 2025-05-26 08:41:54,783 >>   Gradient Accumulation steps = 8
# [INFO|trainer.py:2422] 2025-05-26 08:41:54,783 >>   Total optimization steps = 414
# [INFO|trainer.py:2423] 2025-05-26 08:41:54,786 >>   Number of trainable parameters = 4,399,104
#   1% 5/414 [00:22<29:22,  4.31s/it][INFO|2025-05-26 08:42:17] llamafactory.train.callbacks:143 >> {'loss': 1.2318, 'learning_rate': 4.9988e-05, 'epoch': 0.04, 'throughput': 514.72}
# {'loss': 1.2318, 'grad_norm': 2.60102915763855, 'learning_rate': 4.9988484157560136e-05, 'epoch': 0.04, 'num_input_tokens_seen': 11616}
#   2% 10/414 [00:44<28:52,  4.29s/it][INFO|2025-05-26 08:42:38] llamafactory.train.callbacks:143 >> {'loss': 1.2282, 'learning_rate': 4.9942e-05, 'epoch': 0.07, 'throughput': 508.83}
# {'loss': 1.2282, 'grad_norm': 1.9091310501098633, 'learning_rate': 4.994171922976348e-05, 'epoch': 0.07, 'num_input_tokens_seen': 22448}
#   4% 15/414 [01:05<28:43,  4.32s/it][INFO|2025-05-26 08:43:00] llamafactory.train.callbacks:143 >> {'loss': 0.9835, 'learning_rate': 4.9859e-05, 'epoch': 0.11, 'throughput': 506.57}
# {'loss': 0.9835, 'grad_norm': 1.3623863458633423, 'learning_rate': 4.9859052738933966e-05, 'epoch': 0.11, 'num_input_tokens_seen': 33264}
#   5% 20/414 [01:26<27:18,  4.16s/it][INFO|2025-05-26 08:43:21] llamafactory.train.callbacks:143 >> {'loss': 0.9028, 'learning_rate': 4.9741e-05, 'epoch': 0.14, 'throughput': 503.28}
# {'loss': 0.9028, 'grad_norm': 1.4674351215362549, 'learning_rate': 4.974060367671783e-05, 'epoch': 0.14, 'num_input_tokens_seen': 43440}
#   6% 25/414 [01:49<29:06,  4.49s/it][INFO|2025-05-26 08:43:44] llamafactory.train.callbacks:143 >> {'loss': 0.9293, 'learning_rate': 4.9587e-05, 'epoch': 0.18, 'throughput': 508.92}
# {'loss': 0.9293, 'grad_norm': 1.0872511863708496, 'learning_rate': 4.958654254084355e-05, 'epoch': 0.18, 'num_input_tokens_seen': 55712}
#   7% 30/414 [02:11<28:44,  4.49s/it][INFO|2025-05-26 08:44:06] llamafactory.train.callbacks:143 >> {'loss': 0.8311, 'learning_rate': 4.9397e-05, 'epoch': 0.22, 'throughput': 508.60}
# {'loss': 0.8311, 'grad_norm': 1.1323338747024536, 'learning_rate': 4.9397091089704364e-05, 'epoch': 0.22, 'num_input_tokens_seen': 66864}
#   8% 35/414 [02:34<28:21,  4.49s/it][INFO|2025-05-26 08:44:28] llamafactory.train.callbacks:143 >> {'loss': 1.1260, 'learning_rate': 4.9173e-05, 'epoch': 0.25, 'throughput': 510.11}
# {'loss': 1.126, 'grad_norm': 1.589049220085144, 'learning_rate': 4.9172522023155154e-05, 'epoch': 0.25, 'num_input_tokens_seen': 78592}
#  10% 40/414 [02:54<25:54,  4.16s/it][INFO|2025-05-26 08:44:49] llamafactory.train.callbacks:143 >> {'loss': 0.9973, 'learning_rate': 4.8913e-05, 'epoch': 0.29, 'throughput': 509.75}
# {'loss': 0.9973, 'grad_norm': 1.4851691722869873, 'learning_rate': 4.8913158589983374e-05, 'epoch': 0.29, 'num_input_tokens_seen': 89056}
#  11% 45/414 [03:15<25:04,  4.08s/it][INFO|2025-05-26 08:45:10] llamafactory.train.callbacks:143 >> {'loss': 0.9447, 'learning_rate': 4.8619e-05, 'epoch': 0.33, 'throughput': 508.49}
# {'loss': 0.9447, 'grad_norm': 1.5464154481887817, 'learning_rate': 4.8619374122618854e-05, 'epoch': 0.33, 'num_input_tokens_seen': 99328}
#  12% 50/414 [03:35<25:01,  4.12s/it][INFO|2025-05-26 08:45:30] llamafactory.train.callbacks:143 >> {'loss': 0.7722, 'learning_rate': 4.8292e-05, 'epoch': 0.36, 'throughput': 508.05}
# {'loss': 0.7722, 'grad_norm': 1.4098342657089233, 'learning_rate': 4.8291591499752365e-05, 'epoch': 0.36, 'num_input_tokens_seen': 109728}
#  13% 55/414 [03:58<25:55,  4.33s/it][INFO|2025-05-26 08:45:52] llamafactory.train.callbacks:143 >> {'loss': 0.8478, 'learning_rate': 4.7930e-05, 'epoch': 0.40, 'throughput': 508.58}
# {'loss': 0.8478, 'grad_norm': 1.2663995027542114, 'learning_rate': 4.793028253763633e-05, 'epoch': 0.4, 'num_input_tokens_seen': 121104}
#  14% 60/414 [04:19<26:03,  4.42s/it][INFO|2025-05-26 08:46:14] llamafactory.train.callbacks:143 >> {'loss': 0.8848, 'learning_rate': 4.7536e-05, 'epoch': 0.43, 'throughput': 508.50}
# {'loss': 0.8848, 'grad_norm': 1.3931289911270142, 'learning_rate': 4.7535967310943955e-05, 'epoch': 0.43, 'num_input_tokens_seen': 132144}
#  16% 65/414 [04:39<23:04,  3.97s/it][INFO|2025-05-26 08:46:34] llamafactory.train.callbacks:143 >> {'loss': 0.8679, 'learning_rate': 4.7109e-05, 'epoch': 0.47, 'throughput': 508.14}
# {'loss': 0.8679, 'grad_norm': 1.5896787643432617, 'learning_rate': 4.710921340416431e-05, 'epoch': 0.47, 'num_input_tokens_seen': 142272}
#  17% 70/414 [05:01<24:15,  4.23s/it][INFO|2025-05-26 08:46:56] llamafactory.train.callbacks:143 >> {'loss': 0.8913, 'learning_rate': 4.6651e-05, 'epoch': 0.51, 'throughput': 508.05}
# {'loss': 0.8913, 'grad_norm': 1.8349425792694092, 'learning_rate': 4.665063509461097e-05, 'epoch': 0.51, 'num_input_tokens_seen': 153280}
#  18% 75/414 [05:23<23:37,  4.18s/it][INFO|2025-05-26 08:47:17] llamafactory.train.callbacks:143 >> {'loss': 0.8666, 'learning_rate': 4.6161e-05, 'epoch': 0.54, 'throughput': 508.80}
# {'loss': 0.8666, 'grad_norm': 1.2790281772613525, 'learning_rate': 4.616089246822003e-05, 'epoch': 0.54, 'num_input_tokens_seen': 164432}
#  19% 80/414 [05:42<22:02,  3.96s/it][INFO|2025-05-26 08:47:37] llamafactory.train.callbacks:143 >> {'loss': 0.8930, 'learning_rate': 4.5641e-05, 'epoch': 0.58, 'throughput': 507.59}
# {'loss': 0.893, 'grad_norm': 1.738092064857483, 'learning_rate': 4.564069046941049e-05, 'epoch': 0.58, 'num_input_tokens_seen': 174080}
#  21% 85/414 [06:03<22:56,  4.18s/it][INFO|2025-05-26 08:47:58] llamafactory.train.callbacks:143 >> {'loss': 0.7210, 'learning_rate': 4.5091e-05, 'epoch': 0.61, 'throughput': 507.76}
# {'loss': 0.721, 'grad_norm': 1.2032736539840698, 'learning_rate': 4.509077788637446e-05, 'epoch': 0.61, 'num_input_tokens_seen': 184736}
#  22% 90/414 [06:24<22:43,  4.21s/it][INFO|2025-05-26 08:48:19] llamafactory.train.callbacks:143 >> {'loss': 0.7791, 'learning_rate': 4.4512e-05, 'epoch': 0.65, 'throughput': 507.47}
# {'loss': 0.7791, 'grad_norm': 1.566884160041809, 'learning_rate': 4.4511946273257846e-05, 'epoch': 0.65, 'num_input_tokens_seen': 195328}
#  23% 95/414 [06:46<23:07,  4.35s/it][INFO|2025-05-26 08:48:41] llamafactory.train.callbacks:143 >> {'loss': 0.8737, 'learning_rate': 4.3905e-05, 'epoch': 0.69, 'throughput': 508.30}
# {'loss': 0.8737, 'grad_norm': 1.1567355394363403, 'learning_rate': 4.390502881078296e-05, 'epoch': 0.69, 'num_input_tokens_seen': 206752}
#  24% 100/414 [07:08<22:34,  4.31s/it][INFO|2025-05-26 08:49:03] llamafactory.train.callbacks:143 >> {'loss': 0.7564, 'learning_rate': 4.3271e-05, 'epoch': 0.72, 'throughput': 508.92}
# {'loss': 0.7564, 'grad_norm': 1.6742769479751587, 'learning_rate': 4.3270899106953105e-05, 'epoch': 0.72, 'num_input_tokens_seen': 218096}
#  24% 100/414 [07:08<22:34,  4.31s/it][INFO|trainer.py:3984] 2025-05-26 08:49:03,335 >> Saving model checkpoint to saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/checkpoint-100
# [INFO|configuration_utils.py:693] 2025-05-26 08:49:03,517 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:49:03,517 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2510] 2025-05-26 08:49:03,580 >> tokenizer config file saved in saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/checkpoint-100/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2519] 2025-05-26 08:49:03,581 >> Special tokens file saved in saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/checkpoint-100/special_tokens_map.json
#  25% 105/414 [07:32<23:09,  4.50s/it][INFO|2025-05-26 08:49:26] llamafactory.train.callbacks:143 >> {'loss': 0.7416, 'learning_rate': 4.2610e-05, 'epoch': 0.76, 'throughput': 509.49}
# {'loss': 0.7416, 'grad_norm': 1.686201572418213, 'learning_rate': 4.261046993956531e-05, 'epoch': 0.76, 'num_input_tokens_seen': 230384}
#  27% 110/414 [07:54<22:54,  4.52s/it][INFO|2025-05-26 08:49:49] llamafactory.train.callbacks:143 >> {'loss': 1.0195, 'learning_rate': 4.1925e-05, 'epoch': 0.79, 'throughput': 509.59}
# {'loss': 1.0195, 'grad_norm': 1.5601744651794434, 'learning_rate': 4.192469194234148e-05, 'epoch': 0.79, 'num_input_tokens_seen': 241824}
#  28% 115/414 [08:15<20:36,  4.13s/it][INFO|2025-05-26 08:50:10] llamafactory.train.callbacks:143 >> {'loss': 0.9206, 'learning_rate': 4.1215e-05, 'epoch': 0.83, 'throughput': 509.42}
# {'loss': 0.9206, 'grad_norm': 1.9671311378479004, 'learning_rate': 4.12145522365689e-05, 'epoch': 0.83, 'num_input_tokens_seen': 252512}
#  29% 118/414 [08:29<21:29,  4.36s/it][INFO|trainer.py:2681] 2025-05-26 08:50:26,788 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 512.0022, 'train_samples_per_second': 12.973, 'train_steps_per_second': 0.809, 'train_loss': 0.9188261436203778, 'epoch': 0.85, 'num_input_tokens_seen': 260752}
#  29% 118/414 [08:31<21:24,  4.34s/it]
# [INFO|trainer.py:3984] 2025-05-26 08:50:26,791 >> Saving model checkpoint to saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51
# [INFO|configuration_utils.py:693] 2025-05-26 08:50:27,158 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:50:27,159 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2510] 2025-05-26 08:50:27,244 >> tokenizer config file saved in saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2519] 2025-05-26 08:50:27,245 >> Special tokens file saved in saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =     0.8528
#   num_input_tokens_seen    =     260752
#   total_flos               =   527890GF
#   train_loss               =     0.9188
#   train_runtime            = 0:08:32.00
#   train_samples_per_second =     12.973
#   train_steps_per_second   =      0.809
# Figure saved at: saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51/training_loss.png
# [WARNING|2025-05-26 08:50:27] llamafactory.extras.ploting:148 >> No metric eval_loss to plot.
# [WARNING|2025-05-26 08:50:27] llamafactory.extras.ploting:148 >> No metric eval_accuracy to plot.
# [INFO|modelcard.py:450] 2025-05-26 08:50:27,766 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,936 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/vocab.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/merges.txt
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:12,937 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2323] 2025-05-26 08:52:13,346 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:693] 2025-05-26 08:52:13,558 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:52:13,560 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,608 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/vocab.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,608 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/merges.txt
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,608 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,609 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,609 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,609 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2060] 2025-05-26 08:52:13,609 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2323] 2025-05-26 08:52:13,990 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:693] 2025-05-26 08:52:14,090 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/config.json
# [INFO|configuration_utils.py:765] 2025-05-26 08:52:14,091 >> Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "max_position_embeddings": 32768,
#   "max_window_layers": 24,
#   "model_type": "qwen2",
#   "num_attention_heads": 14,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "tie_word_embeddings": true,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2025-05-26 08:52:14] llamafactory.model.model_utils.kv_cache:143 >> KV cache is enabled for faster generation.
# [INFO|modeling_utils.py:1124] 2025-05-26 08:52:14,150 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/model.safetensors
# [INFO|modeling_utils.py:2167] 2025-05-26 08:52:14,150 >> Instantiating Qwen2ForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1142] 2025-05-26 08:52:14,152 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645
# }
#
# [WARNING|logging.py:328] 2025-05-26 08:52:14,154 >> Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# [INFO|modeling_utils.py:4930] 2025-05-26 08:52:14,769 >> All model checkpoint weights were used when initializing Qwen2ForCausalLM.
#
# [INFO|modeling_utils.py:4938] 2025-05-26 08:52:14,769 >> All the weights of Qwen2ForCausalLM were initialized from the model checkpoint at Qwen/Qwen2-0.5B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2ForCausalLM for predictions without further training.
# [INFO|configuration_utils.py:1097] 2025-05-26 08:52:14,822 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2-0.5B-Instruct/snapshots/c540970f9e29518b1d8f06ab8b24cba66ad77b6d/generation_config.json
# [INFO|configuration_utils.py:1142] 2025-05-26 08:52:14,823 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.1,
#   "temperature": 0.7,
#   "top_k": 20,
#   "top_p": 0.8
# }
#
# [INFO|2025-05-26 08:52:14] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-05-26 08:52:15] llamafactory.model.adapter:143 >> Merged 1 adapter(s).
# [INFO|2025-05-26 08:52:15] llamafactory.model.adapter:143 >> Loaded adapter(s): saves/Qwen2-0.5B-Instruct/lora/train_2025-05-26-08-38-51
# [INFO|2025-05-26 08:52:15] llamafactory.model.loader:143 >> all params: 494,032,768
# [WARNING|2025-05-26 08:52:15] llamafactory.chat.hf_engine:154 >> There is no current event loop, creating a new one.

# %% [markdown]
# ## Fine-tune model via Command Line
#
# It takes ~30min for training.

# %%
import json

args = dict(
  stage="sft",                                               # do supervised fine-tuning
  do_train=True,
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  dataset="identity,alpaca_en_demo",                         # use alpaca and identity datasets
  template="llama3",                                         # use llama3 prompt template
  finetuning_type="lora",                                    # use LoRA adapters to save memory
  lora_target="all",                                         # attach LoRA adapters to all linear layers
  output_dir="llama3_lora",                                  # the path to save LoRA adapters
  per_device_train_batch_size=2,                             # the micro batch size
  gradient_accumulation_steps=4,                             # the gradient accumulation steps
  lr_scheduler_type="cosine",                                # use cosine learning rate scheduler
  logging_steps=5,                                           # log every 5 steps
  warmup_ratio=0.1,                                          # use warmup scheduler
  save_steps=1000,                                           # save checkpoint every 1000 steps
  learning_rate=5e-5,                                        # the learning rate
  num_train_epochs=3.0,                                      # the epochs of training
  max_samples=500,                                           # use 500 examples in each dataset
  max_grad_norm=1.0,                                         # clip gradient norm to 1.0
  loraplus_lr_ratio=16.0,                                    # use LoRA+ algorithm with lambda=16.0
  fp16=True,                                                 # use float16 mixed precision training
  report_to="none",                                          # disable wandb logging
)

json.dump(args, open("train_llama3.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/

# !llamafactory-cli train train_llama3.json

# %% [markdown]
# ## Infer the fine-tuned model

# %%
from llamafactory.chat import ChatModel
from llamafactory.extras.misc import torch_gc

# %cd /content/LLaMA-Factory/

args = dict(
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                        # load the saved LoRA adapters
  template="llama3",                                         # same to the one in training
  finetuning_type="lora",                                    # same to the one in training
)
chat_model = ChatModel(args)

messages = []
print("Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.")
while True:
  query = input("\nUser: ")
  if query.strip() == "exit":
    break
  if query.strip() == "clear":
    messages = []
    torch_gc()
    print("History has been removed.")
    continue

  messages.append({"role": "user", "content": query})
  print("Assistant: ", end="", flush=True)

  response = ""
  for new_text in chat_model.stream_chat(messages):
    print(new_text, end="", flush=True)
    response += new_text
  print()
  messages.append({"role": "assistant", "content": response})

torch_gc()

# %% [markdown]
# ## Merge the LoRA adapter and optionally upload model
#
# NOTE: the Colab free version has merely 12GB RAM, where merging LoRA of a 8B model needs at least 18GB RAM, thus you **cannot** perform it in the free version.

# %%
# !huggingface-cli login

# %%
import json

args = dict(
  model_name_or_path="meta-llama/Meta-Llama-3-8B-Instruct", # use official non-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                       # load the saved LoRA adapters
  template="llama3",                                        # same to the one in training
  finetuning_type="lora",                                   # same to the one in training
  export_dir="llama3_lora_merged",                          # the path to save the merged model
  export_size=2,                                            # the file shard size (in GB) of the merged model
  export_device="cpu",                                      # the device used in export, can be chosen from `cpu` and `auto`
  # export_hub_model_id="your_id/your_model",               # the Hugging Face hub ID to upload model
)

json.dump(args, open("merge_llama3.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/

# !llamafactory-cli export merge_llama3.json
